# %%
import pandas as pd
import numpy as np

# %%
from zipfile import ZipFile

# %%
def gen_store_ts_feat():
    z = ZipFile('./data/train.zip','r')
    df_train = pd.read_csv(z.open('train.csv'))
    df_train = df_train[df_train.Open!=0]
    y = df_train
    df_train = df_train[['Store','DayOfWeek','Date','Promo','StateHoliday','SchoolHoliday','Sales']]
    return df_train

# %%
def gen_store_feat(log=True):
    df_store = pd.read_csv('./data/store.csv')
    if log:
        df_store.CompetitionDistance.fillna(df_store.CompetitionDistance.mean(),inplace=True)
        df_store.loc[:,'CompetitionDistance'] = df_store.loc[:,'CompetitionDistance'].map(lambda n:int(np.log(n)))
    df_store.loc[:,'CompetitionOpenSinceMonth'] = df_store.CompetitionOpenSinceMonth.map(np.isnan)
    df_store = df_store[['Store','StoreType','Assortment','CompetitionDistance','CompetitionOpenSinceMonth','Promo2']]
    return df_store

# %%
def get_X_y(df_train,df_store):
    df = pd.merge(df_train,df_store,on='Store',how='outer')
    y = df.Sales
    df = df[[c for c in df.columns if c!='Sales']]
    df = df.applymap(str)
    dv = DictVectorizer()
    X = dv.fit_transform(df.to_dict('records'))
    return X,y

# %%
df_store
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a                    7
# 1         2         a          a                    6
# 2         3         a          a                    9
# 3         4         c          c                    6
# 4         5         a          a                   10
# 5         6         a          a                    5
# 6         7         a          c                   10
# 7         8         a          a                    8
# 8         9         a          c                    7
# 9        10         a          a                    8
# 10       11         a          c                    6
# 11       12         a          c                    6
# 12       13         d          a                    5
# 13       14         a          a                    7
# 14       15         d          c                    8
# 15       16         a          c                    8
# 16       17         a          a                    3
# 17       18         d          c                    9
# 18       19         a          c                    8
# 19       20         d          a                    7
# 20       21         c          c                    6
# 21       22         a          a                    6
# 22       23         d          a                    8
# 23       24         a          c                    8
# 24       25         c          a                    6
# 25       26         d          a                    7
# 26       27         a          a                    4
# 27       28         a          a                    7
# 28       29         d          c                    7
# 29       30         a          a                    3
# ...     ...       ...        ...                  ...
# 1085   1086         a          a                    5
# 1086   1087         d          c                    7
# 1087   1088         a          a                    8
# 1088   1089         d          a                    8
# 1089   1090         a          a                    5
# 1090   1091         a          c                    9
# 1091   1092         a          a                    5
# 1092   1093         c          c                    9
# 1093   1094         d          a                    7
# 1094   1095         a          a                    6
# 1095   1096         a          c                    7
# 1096   1097         b          b                    6
# 1097   1098         a          a                    7
# 1098   1099         a          c                    5
# 1099   1100         a          a                    6
# 1100   1101         d          c                    8
# 1101   1102         a          a                    6
# 1102   1103         d          c                    7
# 1103   1104         d          a                    5
# 1104   1105         c          c                    5
# 1105   1106         a          c                    8
# 1106   1107         a          a                    7
# 1107   1108         a          a                    6
# 1108   1109         c          a                    8
# 1109   1110         c          c                    6
# 1110   1111         a          a                    7
# 1111   1112         c          c                    7
# 1112   1113         a          c                    9
# 1113   1114         a          c                    6
# 1114   1115         d          c                    8
#
#      CompetitionOpenSinceMonth  Promo2
# 0                        False       0
# 1                        False       1
# 2                        False       1
# 3                        False       0
# 4                        False       0
# 5                        False       0
# 6                        False       0
# 7                        False       0
# 8                        False       0
# 9                        False       0
# 10                       False       1
# 11                        True       1
# 12                        True       1
# 13                       False       1
# 14                       False       1
# 15                        True       0
# 16                       False       1
# 17                       False       1
# 18                        True       1
# 19                       False       1
# 20                       False       1
# 21                        True       1
# 22                       False       0
# 23                       False       1
# 24                       False       0
# 25                        True       0
# 26                       False       1
# 27                       False       1
# 28                        True       0
# 29                       False       1
# ...                        ...     ...
# 1085                     False       1
# 1086                     False       0
# 1087                     False       1
# 1088                     False       0
# 1089                      True       1
# 1090                      True       0
# 1091                     False       1
# 1092                     False       0
# 1093                     False       1
# 1094                     False       1
# 1095                      True       1
# 1096                     False       0
# 1097                     False       0
# 1098                     False       1
# 1099                      True       1
# 1100                     False       0
# 1101                     False       1
# 1102                     False       1
# 1103                     False       1
# 1104                     False       1
# 1105                     False       1
# 1106                     False       1
# 1107                     False       0
# 1108                     False       1
# 1109                     False       0
# 1110                     False       1
# 1111                     False       0
# 1112                      True       0
# 1113                      True       0
# 1114                      True       1
#
# [1115 rows x 6 columns]

# %%
df = pd.merge(df_train,df_store,on='Store',how='outer')

# %%
y = df.Sales

# %%
df = df[[c for c in df.columns if c!='Sales']]

# %%
df = df.applymap(str)

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
dv = DictVectorizer()

# %%
df
# Out:
#        Store DayOfWeek        Date Promo StateHoliday SchoolHoliday StoreType  \
# 0          1         5  2015-07-31     1            0             1         c
# 1          1         4  2015-07-30     1            0             1         c
# 2          1         3  2015-07-29     1            0             1         c
# 3          1         2  2015-07-28     1            0             1         c
# 4          1         1  2015-07-27     1            0             1         c
# 5          1         6  2015-07-25     0            0             0         c
# 6          1         5  2015-07-24     0            0             0         c
# 7          1         4  2015-07-23     0            0             0         c
# 8          1         3  2015-07-22     0            0             0         c
# 9          1         2  2015-07-21     0            0             0         c
# 10         1         1  2015-07-20     0            0             0         c
# 11         1         6  2015-07-18     0            0             0         c
# 12         1         5  2015-07-17     1            0             0         c
# 13         1         4  2015-07-16     1            0             0         c
# 14         1         3  2015-07-15     1            0             0         c
# 15         1         2  2015-07-14     1            0             0         c
# 16         1         1  2015-07-13     1            0             0         c
# 17         1         6  2015-07-11     0            0             0         c
# 18         1         5  2015-07-10     0            0             0         c
# 19         1         4  2015-07-09     0            0             0         c
# 20         1         3  2015-07-08     0            0             0         c
# 21         1         2  2015-07-07     0            0             0         c
# 22         1         1  2015-07-06     0            0             0         c
# 23         1         6  2015-07-04     0            0             0         c
# 844363          a                   7                     False      0
# 844364          a                   7                     False      0
# 844365          a                   7                     False      0
# 844366          a                   7                     False      0
# 844367          a                   7                     False      0
# 844368          a                   7                     False      0
# 844369          a                   7                     False      0
# 844370          a                   7                     False      0
# 844371          a                   7                     False      0
# 844372          a                   7                     False      0
# 844373          a                   7                     False      0
# 844374          a                   7                     False      0
# 844375          a                   7                     False      0
# 844376          a                   7                     False      0
# 844377          a                   7                     False      0
# 844378          a                   7                     False      0
# 844379          a                   7                     False      0
# 844380          a                   7                     False      0
# 844381          a                   7                     False      0
# 844382          a                   7                     False      0
# 844383          a                   7                     False      0
# 844384          a                   7                     False      0
# 844385          a                   7                     False      0
# 844386          a                   7                     False      0
# 844387          a                   7                     False      0
# 844388          a                   7                     False      0
# 844389          a                   7                     False      0
# 844390          a                   7                     False      0
# 844391          a                   7                     False      0
#
# [844392 rows x 11 columns]

# %%
X = dv.fit_transform(df.to_dict('records'))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-34-1aba2a54758f> in <module>()
# ----> 1 X = dv.fit_transform(df.to_dict('records'))
#
# C:\Anaconda\lib\site-packages\sklearn\feature_extraction\dict_vectorizer.pyc in fit_transform(self, X, y)
#     222             Feature vectors; always 2-d.
#     223         """
# --> 224         return self._transform(X, fitting=True)
#     225
#     226     def inverse_transform(self, X, dict_type=dict):
#
# C:\Anaconda\lib\site-packages\sklearn\feature_extraction\dict_vectorizer.pyc in _transform(self, X, fitting)
#     191                 map_index[new_val] = vocab[f]
#     192                 vocab[f] = new_val
# --> 193             result_matrix = result_matrix[:, map_index]
#     194
#     195         if self.sparse:
#
# C:\Anaconda\lib\site-packages\scipy\sparse\csr.pyc in __getitem__(self, key)
#     286                 P = extractor(col,self.shape[1]).T        # [1:2,[1,2]]
#     287                 # row is slice, col is sequence.
# --> 288                 return self[row,:]*P
#     289         elif issequence(row):
#     290             # [[1,2],??]
#
# C:\Anaconda\lib\site-packages\scipy\sparse\csr.pyc in __getitem__(self, key)
#     282                      row.step in (1, None))):
#     283                 # col is int or slice with step 1, row is slice with step 1.
# --> 284                 return self._get_submatrix(row, col)
#     285             elif issequence(col):
#     286                 P = extractor(col,self.shape[1]).T        # [1:2,[1,2]]
#
# C:\Anaconda\lib\site-packages\scipy\sparse\csr.pyc in _get_submatrix(self, row_slice, col_slice)
#     414         indptr, indices, data = get_csr_submatrix(M, N,
#     415                 self.indptr, self.indices, self.data,
# --> 416                 int(i0), int(i1), int(j0), int(j1))
#     417
#     418         shape = (i1 - i0, j1 - j0)
#
# MemoryError: bad allocation

# %%
def get_X_y(df_train,df_store):
    df = pd.merge(df_train,df_store,on='Store',how='outer')
    y = df.Sales
    df = df[[c for c in df.columns if c!='Sales']]
    df = df.applymap(str)
    dv = DictVectorizer()
    X = dv.fit_transform(df.to_dict('records'))
    return X,y
